# %%
def fib(num):##fibonaaci number using recurrsion
    if num==0:
        return 0
    if num==1:
        return 1
    
    return(fib(num-1)+fib(num-2))

# %%
fib(9)
# Out:
# 34

# %%
##TC-o(2^n)
##SC-o(2^n)
